# %%
import os
import urllib.request

print("Start Program")

base_url = ['https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_',
            'https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_',
            'https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_',
            'https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_']

filenames = ["yellow_tripdata", "green_tripdata", "fhv_tripdata",  "fhvhv_tripdata"]

year_beginning = 2009
year_ending = 2021

for i in range(4):
    for year in range(2009, 2021):
        for month in range(1, 13):
            month_str = '{0:02d}'.format(month)
            year_month_str = str(year) + "-" + month_str + ".csv"
            try:
                url = base_url[i] + year_month_str
                print(url)

                datasource = urllib.request.urlopen(url)

                merge_file = filenames[i] + ".csv"
                new_file = True
                if not os.path.isfile(merge_file):
                    fp = open(merge_file, "w")
                    new_file = True
                else:  # Else it exists so append without writing the header (to prevent overwriting data within source file)
                    fp = open(merge_file, "a")
                    new_file = False

                count = 0
                while True:
                    line = datasource.readline()
                    if new_file == False and count == 0:    # If downloaded file exists skip header as you already have it from previous file 
                        count += 1
                        continue

                    if not line: # check if csv stream is ended or not
                        break

                    line = line.decode("utf-8").rstrip() # Convert binary value to string and remove the last return character('\r\n')

                    if not line: # skip empty line
                        continue

                    line = line + '\n'
                    fp.write(line)
                    count += 1

                    if count % 50000 == 0:
                        print("Line " + str(count) + " is processed")

                    if count > 1000:
                        break

                fp.close()
            except Exception as e:
                print("An Exception URL", str(e))

print("End Program")
# Out:
# C:\Users\alfre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\alfre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Testing url loader
import os
import urllib.request

# %%
# Testing url loader
import os
import urllib.request

print("Start Program")

base_url = ['https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_',
            'https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_',
            'https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_',
            'https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_']

filenames = ["yellow_tripdata", "green_tripdata", "fhv_tripdata",  "fhvhv_tripdata"]

year_beginning = 2009
year_ending = 2021

for i in range(4):
    for year in range(2009, 2021):
        for month in range(1, 13):
            month_str = '{0:02d}'.format(month)
            year_month_str = str(year) + "-" + month_str + ".csv"
            try:
                url = base_url[i] + year_month_str
                print(url)
            except Exception as e:
                print("An Exception URL", str(e))

print("End Program")
# Out:
# Start Program
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2012-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2014-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2016-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2018-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2012-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2014-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2015-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2016-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2017-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2018-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-12.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-02.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-03.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-04.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-05.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-06.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-07.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-08.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-09.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-10.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-11.csv
# https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2012-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2014-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2015-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2016-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2017-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2018-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2012-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2014-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2015-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2016-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2017-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2018-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2019-12.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-02.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-03.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-04.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-05.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-06.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-07.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-08.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-09.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-10.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-11.csv
# https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-12.csv
# End Program
