# %%
import main_etl
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# Pull .csv files into a parquet file
yellow = pd.read_csv('..\data\sample_yellow_tripdata.csv')
green = pd.read_csv('..\data\sample_green_tripdata.csv')
fhvhv = pd.read_csv('..\data\sample_fhvhv_tripdata.csv')
fhv = pd.read_csv('..\data\sample_fhv_tripdata.csv')

# Convert DataFrame to Apache Arrow Table
yellow_table = pa.Table.from_pandas(yellow)
green_table = pa.Table.from_pandas(green)
fhvhv_table = pa.Table.from_pandas(fhvhv)
fhv_table = pa.Table.from_pandas(fhv)

# Parquet with Brotli compression
pq.write_table(table, '../data/yellow.parquet', compression='GZIP')
pq.write_table(table, '../data/green.parquet', compression='GZIP')
pq.write_table(table, '../data/fhvhv.parquet', compression='GZIP')
pq.write_table(table, '../data/fhv.parquet', compression='GZIP')
# Out:
# Starting program for 8-2021-9
# ==================================================
# ==================================================
# Whole Data Overview
# ==================================================
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-01.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-01.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-01.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-01.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-01.csv
#         Month: 1
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-01.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-01.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-01.csv
#         Month: 1
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-01.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-01.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-01.csv
#         Month: 1
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-02.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-02.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-02.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-02.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-02.csv
#         Month: 2
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-02.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-02.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-02.csv
#         Month: 2
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-02.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-02.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-02.csv
#         Month: 2
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-03.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-03.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-03.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-03.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-03.csv
#         Month: 3
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-03.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-03.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-03.csv
#         Month: 3
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-03.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-03.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-03.csv
#         Month: 3
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-04.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-04.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-04.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-04.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-04.csv
#         Month: 4
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-04.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-04.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-04.csv
#         Month: 4
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-04.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-04.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-04.csv
#         Month: 4
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-05.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-05.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-05.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-05.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-05.csv
#         Month: 5
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-05.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-05.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-05.csv
#         Month: 5
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-05.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-05.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-05.csv
#         Month: 5
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-06.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-06.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-06.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-06.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-06.csv
#         Month: 6
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-06.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-06.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-06.csv
#         Month: 6
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-06.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-06.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-06.csv
#         Month: 6
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-07.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-07.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-07.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-07.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-07.csv
#         Month: 7
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-07.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-07.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-07.csv
#         Month: 7
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-07.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-07.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-07.csv
#         Month: 7
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-08.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-08.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-08.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-08.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-08.csv
#         Month: 8
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-08.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-08.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-08.csv
#         Month: 8
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-08.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-08.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-08.csv
#         Month: 8
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-09.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-09.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-09.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-09.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-09.csv
#         Month: 9
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-09.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-09.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-09.csv
#         Month: 9
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-09.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-09.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-09.csv
#         Month: 9
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-10.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-10.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-10.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-10.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-10.csv
#         Month: 10
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-10.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-10.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-10.csv
#         Month: 10
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-10.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-10.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-10.csv
#         Month: 10
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-11.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-11.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-11.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-11.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-11.csv
#         Month: 11
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-11.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-11.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-11.csv
#         Month: 11
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-11.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-11.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-11.csv
#         Month: 11
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-12.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2009-12.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-12.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-12.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2009-12.csv
#         Month: 12
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-12.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-12.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2009-12.csv
#         Month: 12
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-12.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-12.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2009-12.csv
#         Month: 12
#         Year: 2009
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-01.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-01.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-01.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-01.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-01.csv
#         Month: 1
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-01.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-01.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-01.csv
#         Month: 1
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-01.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-01.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-01.csv
#         Month: 1
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-02.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-02.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-02.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-02.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-02.csv
#         Month: 2
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-02.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-02.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-02.csv
#         Month: 2
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-02.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-02.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-02.csv
#         Month: 2
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-03.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-03.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-03.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-03.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-03.csv
#         Month: 3
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-03.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-03.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-03.csv
#         Month: 3
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-03.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-03.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-03.csv
#         Month: 3
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-04.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-04.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-04.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-04.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-04.csv
#         Month: 4
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-04.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-04.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-04.csv
#         Month: 4
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-04.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-04.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-04.csv
#         Month: 4
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-05.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-05.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-05.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-05.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-05.csv
#         Month: 5
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-05.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-05.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-05.csv
#         Month: 5
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-05.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-05.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-05.csv
#         Month: 5
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-06.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-06.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-06.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-06.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-06.csv
#         Month: 6
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-06.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-06.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-06.csv
#         Month: 6
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-06.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-06.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-06.csv
#         Month: 6
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-07.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-07.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-07.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-07.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-07.csv
#         Month: 7
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-07.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-07.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-07.csv
#         Month: 7
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-07.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-07.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-07.csv
#         Month: 7
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-08.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-08.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-08.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-08.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-08.csv
#         Month: 8
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-08.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-08.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-08.csv
#         Month: 8
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-08.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-08.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-08.csv
#         Month: 8
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-09.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-09.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-09.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-09.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-09.csv
#         Month: 9
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-09.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-09.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-09.csv
#         Month: 9
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-09.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-09.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-09.csv
#         Month: 9
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-10.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-10.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-10.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-10.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-10.csv
#         Month: 10
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-10.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-10.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-10.csv
#         Month: 10
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-10.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-10.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-10.csv
#         Month: 10
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-11.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-11.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-11.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-11.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-11.csv
#         Month: 11
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-11.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-11.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-11.csv
#         Month: 11
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-11.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-11.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-11.csv
#         Month: 11
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-12.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2010-12.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-12.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-12.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2010-12.csv
#         Month: 12
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-12.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-12.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2010-12.csv
#         Month: 12
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-12.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-12.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2010-12.csv
#         Month: 12
#         Year: 2010
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-01.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-01.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-01.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-01.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-01.csv
#         Month: 1
#         Year: 2011
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-01.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-01.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-01.csv
#         Month: 1
#         Year: 2011
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-01.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-01.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-01.csv
#         Month: 1
#         Year: 2011
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-02.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2011-02.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-02.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-02.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2011-02.csv
#         Month: 2
#         Year: 2011
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-02.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-02.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2011-02.csv
#         Month: 2
#         Year: 2011
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-02.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-02.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2011-02.csv
#         Month: 2
#         Year: 2011
# ...
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-01.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-01.csv
#         Month: 1
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-02.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-02.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-02.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-02.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-02.csv
#         Month: 2
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-02.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-02.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-02.csv
#         Month: 2
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-02.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-02.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-02.csv
#         Month: 2
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-03.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-03.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-03.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-03.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-03.csv
#         Month: 3
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-03.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-03.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-03.csv
#         Month: 3
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-03.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-03.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-03.csv
#         Month: 3
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-04.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-04.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-04.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-04.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-04.csv
#         Month: 4
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-04.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-04.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-04.csv
#         Month: 4
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-04.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-04.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-04.csv
#         Month: 4
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-05.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-05.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-05.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-05.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-05.csv
#         Month: 5
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-05.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-05.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-05.csv
#         Month: 5
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-05.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-05.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-05.csv
#         Month: 5
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-06.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-06.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-06.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-06.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-06.csv
#         Month: 6
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-06.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-06.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-06.csv
#         Month: 6
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-06.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-06.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-06.csv
#         Month: 6
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-07.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-07.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-07.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-07.csv and ../data/sample_green_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-07.csv
#         Month: 7
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-07.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-07.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-07.csv
#         Month: 7
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-07.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-07.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-07.csv
#         Month: 7
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-08.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-08.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-08.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-08.csv and ../data/sample_green_tripdata.csv
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-08.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-08.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-08.csv
#         Month: 8
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-08.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-08.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-08.csv
#         Month: 8
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-09.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-09.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-09.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-09.csv and ../data/sample_green_tripdata.csv
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-09.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-09.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-09.csv
#         Month: 9
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-09.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-09.csv and ../data/sample_fhvhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-09.csv
#         Month: 9
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-10.csv ../data/sample_yellow_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2013-10.csv and ../data/sample_yellow_tripdata.csv
# Calling process_url for  https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-10.csv ../data/sample_green_tripdata.csv
# Starting URL processing for https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2013-10.csv and ../data/sample_green_tripdata.csv
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-10.csv ../data/sample_fhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-10.csv and ../data/sample_fhv_tripdata.csv
#
#         HTTP Error 404: Not Found
# The above error occured for the following:
#
#         URL: https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2013-10.csv
#         Month: 10
#         Year: 2013
#         ==================================================
#
# Calling process_url for  https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-10.csv ../data/sample_fhvhv_tripdata.csv
# Starting URL processing for https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2013-10.csv and ../data/sample_fhvhv_tripdata.csv
